# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('laptops.csv')
df
# Out:
#      Unnamed: 0                                           img_link  \
# 0             0  https://rukminim1.flixcart.com/image/312/312/x...
# 1             1  https://rukminim1.flixcart.com/image/312/312/x...
# 2             2  https://rukminim1.flixcart.com/image/312/312/l...
# 3             3  https://rukminim1.flixcart.com/image/312/312/x...
# 4             4  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 979         979  https://rukminim1.flixcart.com/image/312/312/k...
# 980         980  https://rukminim1.flixcart.com/image/312/312/k...
# 981         981  https://rukminim1.flixcart.com/image/312/312/x...
# 982         982  https://rukminim1.flixcart.com/image/312/312/k...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        984 non-null    int64
#  1   img_link          984 non-null    object
#  2   name              984 non-null    object
#  3   price(in Rs.)     984 non-null    int64
#  4   processor         984 non-null    object
#  5   ram               984 non-null    object
#  6   os                984 non-null    object
#  7   storage           984 non-null    object
#  8   display(in inch)  984 non-null    float64
#  9   rating            688 non-null    float64
#  10  no_of_ratings     688 non-null    float64
#  11  no_of_reviews     688 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 92.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  price(in Rs.)  display(in inch)      rating  no_of_ratings  \
# count  984.000000     984.000000        984.000000  688.000000     688.000000
# mean   491.500000   80960.720528         15.148374    4.284884     718.091570
# std    284.200633   57421.220919          1.332078    0.330239    1750.817825
# min      0.000000   15990.000000         11.600000    1.600000       1.000000
# 25%    245.750000   42655.000000         14.000000    4.100000      14.000000
# 50%    491.500000   62990.000000         15.600000    4.300000      90.000000
# 75%    737.250000   94990.000000         15.600000    4.500000     453.000000
# max    983.000000  419990.000000         35.000000    5.000000   15492.000000
#
#        no_of_reviews
# count     688.000000
# mean       83.898256
# std       211.596726
# min         0.000000
# 25%         2.000000
# 50%        11.000000
# 75%        53.500000
# max      2054.000000

# %%
df.head(2)
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
#
#                              name  price(in Rs.)  \
# 0   Lenovo Intel Core i5 11th Gen          62990
# 1  Lenovo V15 G2 Core i3 11th Gen          37500
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
#
#                                    os              storage  display(in inch)  \
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
#
#    rating  no_of_ratings  no_of_reviews
# 0     4.5           14.0            1.0
# 1     4.4           53.0            3.0

# %%
df.tail(2)
# Out:
#      Unnamed: 0                                           img_link  \
# 982         982  https://rukminim1.flixcart.com/image/312/312/k...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                 name  price(in Rs.)  \
# 982   DELL Inspiron Core i3 11th Gen          40990
# 983  ASUS Celeron Dual Core 10th Gen          24540
#
#                                         processor            ram  \
# 982            Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# 983  Intel Celeron Dual Core Processor (10th Gen)  4 GB DDR4 RAM
#
#                                      os              storage  \
# 982  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD
# 983         Windows 11 Operating System           256 GB SSD
#
#      display(in inch)  rating  no_of_ratings  no_of_reviews
# 982              15.6     4.0          801.0          104.0
# 983              14.0     NaN            NaN            NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# img_link              0
# name                  0
# price(in Rs.)         0
# processor             0
# ram                   0
# os                    0
# storage               0
# display(in inch)      0
# rating              296
# no_of_ratings       296
# no_of_reviews       296
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'img_link', 'name', 'price(in Rs.)', 'processor', 'ram', 'os', 'storage', 'display(in inch)', 'rating', 'no_of_ratings', 'no_of_reviews']

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\anuku\AppData\Local\Temp\ipykernel_5596\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
sns.jointplot(x='price(in Rs.)',y='rating',data=df,kind='hex')

# %%
sns.jointplot(x='rating',y='price(in Rs.)',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
df['name'].unique()
# Out:
# array(['Lenovo Intel Core i5 11th Gen', 'Lenovo V15 G2 Core i3 11th Gen',
#        'ASUS TUF Gaming F15 Core i5 10th Gen',
#        'ASUS VivoBook 15 (2022) Core i3 10th Gen',
#        'Lenovo Athlon Dual Core', 'APPLE 2020 Macbook Air M1',
#        'ASUS VivoBook 14 (2021) Celeron Dual Core',
#        'DELL Vostro Ryzen 3 Quad Core 5425U',
#        'RedmiBook Pro Core i5 11th Gen',
#        'acer Aspire 3 Ryzen 3 Dual Core 3250U',
#        'ASUS Vivobook 14 (2022) Core i5 12th Gen',
#        'ASUS Vivobook 15 Core i3 11th Gen', 'ASUS Core i7 11th Gen',
#        'DELL Vostro Core i3 11th Gen',
#        'realme Book (Slim) Core i3 11th Gen',
#        'HP 14s Intel Core i3 11th Gen', 'HP Ryzen 5 Hexa Core 5500U',
#        'MSI Bravo 15 Ryzen 5 Hexa Core AMD R5',
#        'ASUS Zenbook Flip 14 OLED (2022) Touch Panel Core i5 12th Gen',
#        'HP 15s Intel Core i3 12th Gen', 'HP Intel Core i5 11th Gen',
#        'HP Ryzen 3 Quad Core 5300U', 'Lenovo IdeaPad 3 Core i3 11th Gen',
# ...

# %%
df.groupby('name')['price(in Rs.)'].sum()
# Out:
# name
# ALIENWARE Core i7 10th Gen                      664780
# ALIENWARE Core i9 10th Gen                      345390
# APPLE 2020 Macbook Air M1                       480950
# APPLE 2020 Macbook Pro M1                       244980
# APPLE 2021 Macbook Pro M1 Max                   307990
#                                                  ...
# acer Travelmate Core i3 11th Gen                 46040
# acer aspire 5 gaming Core i5 12th Gen            61999
# lenovo Yoga 7 Core i7 11th Gen Intel EVO        105990
# realme Book (Slim) Core i3 11th Gen             140970
# realme Book(Slim) Intel Evo Core i5 11th Gen    119980
# Name: price(in Rs.), Length: 506, dtype: int64

# %%
df.groupby('name')['price(in Rs.)'].value_counts()
# Out:
# name                                          price(in Rs.)
# ALIENWARE Core i7 10th Gen                    199990           1
#                                               214790           1
#                                               250000           1
# ALIENWARE Core i9 10th Gen                    345390           1
# APPLE 2020 Macbook Air M1                     86990            3
#                                                               ..
# acer Travelmate Core i3 11th Gen              46040            1
# acer aspire 5 gaming Core i5 12th Gen         61999            1
# lenovo Yoga 7 Core i7 11th Gen Intel EVO      105990           1
# realme Book (Slim) Core i3 11th Gen           46990            3
# realme Book(Slim) Intel Evo Core i5 11th Gen  59990            2
# Name: price(in Rs.), Length: 754, dtype: int64
