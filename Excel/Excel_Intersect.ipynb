# %% [markdown]
# Here Pyforest library is working. which means that we doesn't need to import any library.It automatically import it for us.

# %%
df = pd.read_csv('batting.csv')
df.head(2)
# Out:
#    MatchID  InningsNo Team        PlayerName  MatchPlayingOrder   BowlerName  \
# 0        1          1  CSK  Ruturaj  Gaikwad                  1  Umesh Yadav
# 1        1          1  CSK      Devon Conway                  2  Umesh Yadav
#
#                         OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  \
# 0   c Nitish Rana b Umesh Yadav     0      4         4     0     0       0
# 1  c Shreyas Iyer b Umesh Yadav     3      8         5     3     0       0
#
#    Fours  Sixes StrikeRate  WicketNo  AgainstFast  AgainstSpin
# 0      0      0       0.00       3.0            3            0
# 1      0      0      37.50       2.0            8            0

# %%
dff = pd.read_csv('bowling.csv')
dff.head()
# Out:
#    MatchID  InningsNo Team           PlayerName  Overs  Maidens  Runs  \
# 0        1          1  KKR          Umesh Yadav    4.0        0    20
# 1        1          1  KKR          Shivam Mavi    4.0        0    35
# 2        1          1  KKR  Varun Chakaravarthy    4.0        0    23
# 3        1          1  KKR         Sunil Narine    4.0        0    15
# 4        1          1  KKR        Andre Russell    4.0        0    38
#
#    Wickets  Wides  NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# 0        2      2        1     5.00             1                     24
# 1        0      1        1     8.75             2                     24
# 2        1      1        0     5.75             3                     24
# 3        0      0        0     3.75             4                     24
# 4        1      0        0     9.50             5                     24
#
#    DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# ...

# %%
new_file = dff[df.apply(tuple).isin(dff.apply(tuple))]
print(new_file)
# Out:
#      MatchID  InningsNo Team PlayerName  Overs  Maidens  Runs  Wickets  Wides  \
# 0        1.0        1.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 1        1.0        1.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 2        1.0        1.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 3        1.0        1.0  NaN        NaN    NaN      NaN  15.0      NaN    NaN
# 4        1.0        1.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# ..       ...        ...  ...        ...    ...      ...   ...      ...    ...
# 852      NaN        2.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 853      NaN        2.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 854      NaN        2.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 855      NaN        2.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
# 856      NaN        2.0  NaN        NaN    NaN      NaN   NaN      NaN    NaN
#
# ...

# %%
print(df.columns.to_list())
# Out:
# ['MatchID', 'InningsNo', 'Team', 'PlayerName', 'MatchPlayingOrder', 'BowlerName', 'OutDesc', 'Runs', 'Balls', 'DotBalls', 'Ones', 'Twos', 'Threes', 'Fours', 'Sixes', 'StrikeRate', 'WicketNo', 'AgainstFast', 'AgainstSpin']

# %%
print(dff.columns.tolist())
# Out:
# ['MatchID', 'InningsNo', 'Team', 'PlayerName', 'Overs', 'Maidens', 'Runs', 'Wickets', 'Wides', 'NoBalls', 'Economy', 'BowlingOrder', 'TotalLegalBallsBowled', 'DotBalls', 'Ones', 'Twos', 'Threes', 'Fours', 'Sixes', 'StrikeRate']

# %%
new_file = df[df.apply(tuple).isin(dff.apply(tuple))]
#print(new_file)
pd.DataFrame(new_file)
# Out:
#       MatchID  InningsNo Team PlayerName  MatchPlayingOrder BowlerName  \
# 0         1.0        1.0  NaN        NaN                NaN        NaN
# 1         1.0        1.0  NaN        NaN                NaN        NaN
# 2         1.0        1.0  NaN        NaN                NaN        NaN
# 3         1.0        1.0  NaN        NaN                NaN        NaN
# 4         1.0        1.0  NaN        NaN                NaN        NaN
# ...       ...        ...  ...        ...                ...        ...
# 1623      NaN        NaN  NaN        NaN                NaN        NaN
# 1624      NaN        NaN  NaN        NaN                NaN        NaN
# 1625      NaN        NaN  NaN        NaN                NaN        NaN
# 1626      NaN        NaN  NaN        NaN                NaN        NaN
# 1627      NaN        NaN  NaN        NaN                NaN        NaN
#
#      OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  Fours  Sixes  \
# ...

# %%
with open('batting.csv', 'r') as csv1, open('bowling.csv', 'r') as csv2:  # Import CSV files
    import1 = csv1.readlines()
    import2 = csv2.readlines()

# %%
with open('data_diff.csv', 'w') as outFile:         # Create CSV file with differences
    for row in import2:
        if row not in import1:
            print(outFile.write(row))
# Out:
# 167
# 62
# 62
# 72
# 64
# 64
# 66
# 59
# 68
# 63
# 60
# 66
# 64
# 64
# 60
# 66
# 62
# 59
# 61
# 63
# 62
# 64
# 61
# 66
# 68
# 62
# 64
# 65
# 66
# 62
# 66
# 60
# 62
# 69
# 64
# 64
# 63
# 64
# 63
# 62
# 70
# 61
# 60
# 62
# 65
# 65
# 69
# 68
# 63
# 68
# 63
# 64
# 62
# 65
# 68
# 69
# 65
# 59
# 60
# 66
# 63
# 67
# 65
# 62
# 62
# 61
# 64
# 64
# 71
# 63
# 61
# 70
# 62
# 63
# 63
# 61
# 67
# 67
# 64
# 65
# 58
# 67
# 60
# 62
# 62
# 62
# 69
# 64
# 60
# 66
# 65
# 63
# 66
# 64
# 66
# 64
# 61
# 60
# 64
# 61
# 65
# 62
# 66
# 62
# 69
# 66
# 59
# 68
# 65
# 64
# 61
# 64
# 65
# 64
# 65
# 62
# 58
# 62
# 63
# 69
# 65
# 65
# 67
# 68
# 57
# 67
# 67
# 66
# 63
# 65
# 68
# 69
# 70
# 69
# 62
# 59
# 63
# 63
# 66
# 61
# 62
# 64
# 66
# 65
# 61
# 69
# 66
# 61
# 65
# 70
# 69
# 64
# 64
# 64
# 63
# 64
# 63
# 71
# 61
# 62
# 63
# 64
# 62
# 58
# 64
# 63
# 71
# 62
# 64
# 61
# 63
# 67
# 63
# 65
# 63
# 59
# 65
# 65
# 64
# 67
# 62
# 67
# 62
# 65
# 67
# 67
# 66
# 64
# 67
# 68
# 64
# 70
# 63
# 62
# 61
# 68
# 70
# 64
# 65
# ...

# %%
from csv_diff import load_csv, compare
diff = compare(
    load_csv(open("batting.csv")),
    load_csv(open("bowling.csv"))
)
diff
#print(pd.DataFrame(diff))
# Out:
# {'added': [{'MatchID': '1',
#    'InningsNo': '1',
#    'Team': 'KKR',
#    'PlayerName': 'Umesh Yadav',
#    'Overs': '4.0',
#    'Maidens': '0',
#    'Runs': '20',
#    'Wickets': '2',
#    'Wides': '2',
#    'NoBalls': '1',
#    'Economy': '5.0',
#    'BowlingOrder': '1',
#    'TotalLegalBallsBowled': '24',
#    'DotBalls': '15',
#    'Ones': '7',
#    'Twos': '0',
#    'Threes': '0',
#    'Fours': '1',
#    'Sixes': '1',
#    'StrikeRate': '12.0'},
#   {'MatchID': '1',
#    'InningsNo': '1',
#    'Team': 'KKR',
#    'PlayerName': 'Shivam Mavi',
#    'Overs': '4.0',
#    'Maidens': '0',
#    'Runs': '35',
#    'Wickets': '0',
#    'Wides': '1',
#    'NoBalls': '1',
#    'Economy': '8.75',
#    'BowlingOrder': '2',
#    'TotalLegalBallsBowled': '24',
#    'DotBalls': '12',
#    'Ones': '7',
#    'Twos': '1',
#    'Threes': '0',
#    'Fours': '3',
#    'Sixes': '2',
#    'StrikeRate': '0.0'},
#   {'MatchID': '1',
#    'InningsNo': '1',
#    'Team': 'KKR',
# ...
