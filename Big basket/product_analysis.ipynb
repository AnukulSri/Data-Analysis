# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('BigBasket.csv')
df
# Out:
#                                             ProductName                Brand  \
# 0                                         Onion (Loose)               Fresho
# 1                                                 Onion               Fresho
# 2                                         Onion (Loose)               Fresho
# 3                                                 Onion               Fresho
# 4                                         Onion (Loose)               Fresho
# ...                                                 ...                  ...
# 8203  Foil Alphabet Balloon - Letter V, Party Decor,...              Bvishal
# 8204  Decoration Balls - Used For Parties, Unique De...              Bvishal
# 8205                    Foundation Blending Brush - 230                  PAC
# 8206                          One Week Immunity Booster  The Healthy Company
# 8207  Blush & Glow - Green Apple Apricot Gel Scrub, ...                Lakme
#
#        Price  DiscountPrice  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8208 entries, 0 to 8207
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductName    8208 non-null   object
#  1   Brand          8208 non-null   object
#  2   Price          8208 non-null   float64
#  3   DiscountPrice  8208 non-null   float64
#  4   Image_Url      8208 non-null   object
#  5   Quantity       8208 non-null   object
#  6   Category       8208 non-null   object
#  7   SubCategory    8208 non-null   object
#  8   Absolute_Url   8208 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 577.2+ KB

# %%
df.describe()
# Out:
#               Price  DiscountPrice
# count   8208.000000    8208.000000
# mean     545.418589     356.907968
# std      664.546512     438.097837
# min        5.000000       3.000000
# 25%      190.000000     129.000000
# 50%      360.000000     238.000000
# 75%      650.000000     429.000000
# max    10140.000000    7605.000000

# %%
df.head()
# Out:
#      ProductName   Brand   Price  DiscountPrice  \
# 0  Onion (Loose)  Fresho   69.75           52.0
# 1          Onion  Fresho  174.35          130.0
# 2  Onion (Loose)  Fresho   34.87           26.0
# 3          Onion  Fresho   69.74           52.0
# 4  Onion (Loose)  Fresho  174.37          129.0
#
#                                            Image_Url Quantity  \
# 0  https://www.bigbasket.com/media/uploads/p/l/40...     2 kg
# 1  https://www.bigbasket.com/media/uploads/p/l/12...     5 kg
# 2  https://www.bigbasket.com/media/uploads/p/l/10...     1 kg
# 3  https://www.bigbasket.com/media/uploads/p/l/12...     2 kg
# 4  https://www.bigbasket.com/media/uploads/p/l/10...     5 kg
#
#               Category             SubCategory  \
# 0  Fruits & Vegetables  Potato, Onion & Tomato
# 1  Fruits & Vegetables  Potato, Onion & Tomato
# 2  Fruits & Vegetables  Potato, Onion & Tomato
# 3  Fruits & Vegetables  Potato, Onion & Tomato
# 4  Fruits & Vegetables  Potato, Onion & Tomato
#
# ...

# %%
df.tail()
# Out:
#                                             ProductName                Brand  \
# 8203  Foil Alphabet Balloon - Letter V, Party Decor,...              Bvishal
# 8204  Decoration Balls - Used For Parties, Unique De...              Bvishal
# 8205                    Foundation Blending Brush - 230                  PAC
# 8206                          One Week Immunity Booster  The Healthy Company
# 8207  Blush & Glow - Green Apple Apricot Gel Scrub, ...                Lakme
#
#       Price  DiscountPrice                                          Image_Url  \
# 8203   49.0           25.0  https://www.bigbasket.com/media/uploads/p/l/40...
# 8204  399.0          249.0  https://www.bigbasket.com/media/uploads/p/l/40...
# 8205  465.0          232.5  https://www.bigbasket.com/media/uploads/p/l/40...
# 8206  799.0          799.0  https://www.bigbasket.com/media/uploads/p/l/40...
# 8207  250.0          175.0  https://www.bigbasket.com/media/uploads/p/l/40...
#
# ...

# %%
df.isnull().sum()
# Out:
# ProductName      0
# Brand            0
# Price            0
# DiscountPrice    0
# Image_Url        0
# Quantity         0
# Category         0
# SubCategory      0
# Absolute_Url     0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['ProductName', 'Brand', 'Price', 'DiscountPrice', 'Image_Url', 'Quantity', 'Category', 'SubCategory', 'Absolute_Url']

# %%
df.groupby('Brand')['Brand'].count()
# Out:
# Brand
# 109°F           1
# 24 Mantra       5
# 5:15PM          7
# A-1 Chips       1
# AEROFIL         1
#                ..
# nature's eco    1
# s.Oliver        6
# sumeru          2
# suny            6
# tagz            1
# Name: Brand, Length: 842, dtype: int64

# %%
df.loc[:10]
# Out:
#                                           ProductName   Brand   Price  \
# 0                                       Onion (Loose)  Fresho   69.75
# 1                                               Onion  Fresho  174.35
# 2                                       Onion (Loose)  Fresho   34.87
# 3                                               Onion  Fresho   69.74
# 4                                       Onion (Loose)  Fresho  174.37
# 5   Farm Eggs - Table Tray, Medium, Antibiotic Res...  Fresho  110.00
# 6   Farm Eggs - Table Tray, Medium, Antibiotic Res...  Fresho  210.00
# 7                                      Potato (Loose)  Fresho   50.32
# 8                                              Potato  Fresho  100.65
# 9                                      Eggs - Regular  Fresho  250.00
# 10  Farm Eggs - Regular, Medium, Antibiotic Residu...  Fresho   50.00
#
#     DiscountPrice                                          Image_Url Quantity  \
# ...

# %%
df['ProductName']
# Out:
# 0                                           Onion (Loose)
# 1                                                   Onion
# 2                                           Onion (Loose)
# 3                                                   Onion
# 4                                           Onion (Loose)
#                               ...
# 8203    Foil Alphabet Balloon - Letter V, Party Decor,...
# 8204    Decoration Balls - Used For Parties, Unique De...
# 8205                      Foundation Blending Brush - 230
# 8206                            One Week Immunity Booster
# 8207    Blush & Glow - Green Apple Apricot Gel Scrub, ...
# Name: ProductName, Length: 8208, dtype: object

# %%
df['ProductName'].max()
# Out:
# "sun'nil Sun Protection Lotion - Normal to Dry Skin, Jojoba & Grape Seed"

# %% [markdown]
# # if we use aggregation on string then it will print the data on behalf of its length

# %%
a = df['ProductName']=='sun\'nil Sun Protection Lotion - Normal to Dry Skin, Jojoba & Grape Seed'
df[a]
# Out:
#                                             ProductName       Brand  Price  \
# 3926  sun'nil Sun Protection Lotion - Normal to Dry ...  Just Herbs  795.0
#
#       DiscountPrice                                          Image_Url  \
# 3926          557.0  https://www.bigbasket.com/media/uploads/p/l/40...
#
#      Quantity          Category SubCategory  \
# 3926   100 ml  Beauty & Hygiene   Body Care
#
#                                            Absolute_Url
# 3926  https://www.bigbasket.com/pd/40175164/just-her...
